# %%
x = 1
y = x / 3
z = y * 3
if x == z:
    print("Trump")
else:
    print("Biden")
# Out:
# Trump
# Trump

# %%
numbers = []
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
a = int(input())
print(a)
# Out:
# 5

# %%
for _ in range(100):
    tmp = 10

# %% [markdown]
# строки неимзменяемы в питоне

# %%
s = 'cat'
s = 'rabbit'
print(s)
# Out:
# rabbit

# %% [markdown]
# а листы изменяемый
# то есть мы не создаем новый объект и не перессылаемся на него и не уменьшаем счетчик

# %%
v = 2
u = v
u = 3
print(v)
# Out:
# 2

# %%
l = ['c', 'a', 't']
k = l
k[2] = 'r'
print(''.join(l))
# Out:
# car

# %%
l = ['c', 'a', 't']
k = l
k = []
print(''.join(l))
# Out:
# cat

# %%
s = "Name+surname+secondname"
values = s.split("+")
print(values)
text = "+".join(values)
print(text)
# Out:
# ['Name', 'surname', 'secondname']
# Name+surname+secondname

# %%
zoo = ['cat', 'hippo', 'bear']
tmp = [x for x in zoo if len(x) > 4]
print(tmp)
# Out:
# ['cat', 'hippo', 'bear']
