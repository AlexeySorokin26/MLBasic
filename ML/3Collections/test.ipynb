# %%
x = 1
y = x / 3
z = y * 3
if x == z:
    print("Trump")
else:
    print("Biden")
# Out:
# Trump

# %% [markdown]
# Оптимизация происходит по логике что должны получить что уже было по простой математике

# %%
numbers = []
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %% [markdown]
# строки неимзменяемы в питоне

# %%
s = 'cat'
s = 'rabbit'
print(s)
# Out:
# rabbit

# %% [markdown]
# а листы изменяемый
# то есть мы не создаем новый объект и не перессылаемся на него и не уменьшаем счетчик

# %%
v = 2
u = v
u = 3
print(v)
# Out:
# 2

# %%
l = ['c', 'a', 't']
k = l
k[2] = 'r'
print(''.join(l))
# Out:
# car

# %%
l = ['c', 'a', 't']
k = l
k = []
print(''.join(l))
# Out:
# cat
