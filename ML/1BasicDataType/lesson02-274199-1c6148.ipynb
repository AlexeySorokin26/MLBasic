# %%
import random

num = random.randint(1, 100)

num
# Out:
# 99

# %% [markdown]
# https://pypi.org/

# %% [markdown]
# http://python.org/

# %%
name = 'Anna'

# %%
NaMe = 'Bob'

# %%
name
# Out:
# 'Anna'

# %%
NaMe
# Out:
# 'Bob'

# %% [markdown]
# snake_case  - змеинный стиль

# %%
my_name_is = 'John'

# %% [markdown]
# Не создаем a, b, x, 1_name , MyName, myName

# %%
a = 10

# %%
a
# Out:
# 10

# %%
print(a)
# Out:
# 10

# %%
моё_имя = 'Мэри'

# %%
моё_имя
# Out:
# 'Мэри'

# %%
_ = 10

# %%
_
# Out:
# 10

# %%
NAME = 'John'

# %%
number = 10 # Это правильно

# %%
number_1=11 # Это правильно

# %%
1_number = 100
# Out:
#   Cell In[21], line 1
#     1_number = 100
#      ^
# SyntaxError: invalid decimal literal

# %%
name = 'Mary'
age = 25
print(name)
print(age)
# Out:
# Mary
# 25

# %%
name = "Mary"
age = 25
print(name)
print(age)
# Out:
# Mary
# 25

# %%
name = '''Mary'''
age = 25
print(name)
print(age)
# Out:
# Mary
# 25

# %%
name = """Mary"""
age = 25
print(name)
print(age)
# Out:
# Mary
# 25

# %%
my_str = 'My name's Mary'
# Out:
#   Cell In[26], line 1
#     my_str = 'My name's Mary'
#                             ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
my_str = "My name's Mary"

# %%
my_str
# Out:
# "My name's Mary"

# %%
my_str = 'My name"s Mary'
print(my_str)
# Out:
# My name"s Mary

# %%
my_text = '''Привет, Мир.
Мы изучаем python.
   Ура!!
'''
print(my_text)
# Out:
# Привет, Мир.
# Мы изучаем python.
#    Ура!!

# %%
my_text = 'Привет, Мир.
Мы изучаем python.
   Ура!!
'
print(my_text)
# Out:
#   Cell In[32], line 1
#     my_text = 'Привет, Мир.
#               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
my_text = 'Привет, Мир. \
Мы изучаем python. \
   Ура!! \
'
print(my_text)
# Out:
# Привет, Мир. Мы изучаем python.    Ура!!

# %%
name = """Mary"""; age = 25; print(name);  print(age)  # Так не пишем
# Out:
# Mary
# 25

# %%
name = """Mary"""  # строки  тип str
age = 25 # целые числа -  тип int
number = 17.3 # дробные числа - тип float
male = False # булев тип - тип bool - True и False
print(name)
print(age)
print(number)
print(male)
# Out:
# Mary
# 25
# 17.3
# False
# Mary 25 17.3 False

# %%
print(name, age, number, male)
print(name, age, number, male, sep='-!-')
# Out:
# Mary 25 17.3 False
# Mary-!-25-!-17.3-!-False

# %%
name = """Mary"""  # строки  тип str
age = 25 # целые числа -  тип int
number = 17.3 # дробные числа - тип float
male = False # булев тип - тип bool - True и False
print(name, end=' Перенос на новую строку\n')
print(age, end=' Перенос на новую строку 2 \n')
print(number, end=' Перенос на новую строку 3')
print(male, end=' Конец ! ')
# Out:
# Mary Перенос на новую строку
# 25 Перенос на новую строку 2
# 17.3 Перенос на новую строку 3False Конец !

# %%
male
# Out:
# False

# %%
num = input()

# %%
num
# Out:
# '1000'

# %%
num = input('Введите число: ')

# %%
num
# Out:
# '1200'

# %%
name = """Mary"""  # строки  тип str
age = 25 # целые числа -  тип int
number = 17.3 # дробные числа - тип float
male = False # булев тип - тип bool - True и False
print(type(name))
print(type(age))
print(type(number))
print(type(male))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
num_1 = input('Введите число: ')
print(type(num_1))
print(num_1)
# Out:
# <class 'str'>
# 123

# %%
num1 = 123
num2 = 456
print(type(num1))
print(type(num2))
num3 = num1 + num2
print(num3)
print(type(num3))
num4 = num2 - num1
print(num4)
print(type(num4))
num5 = num1 - num2
print(num5)
print(type(num5))

num6 = num1 * num2
print(num6)
print(type(num6))

num7 = num1 / num2
print(num7)
print(type(num7))

num8 = num2 % num1
print(num8)
print(type(num8))

num9 = num2 // num1
print(num9)
print(type(num9))
# Out:
# <class 'int'>
# <class 'int'>
# 579
# <class 'int'>
# 333
# <class 'int'>
# -333
# <class 'int'>
# 56088
# <class 'int'>
# 0.26973684210526316
# <class 'float'>
# 87
# <class 'int'>
# 3
# <class 'int'>

# %%
num_1 = 10
num_2 = 2
num_3 = num_1 / num_2
print(num_3)
print(type(num_3))
# Out:
# 5.0
# <class 'float'>

# %%
num_1 = 10
num_2 = 1.1
num_3 = num_1 - num_2
print(num_3)
print(type(num_3))
# Out:
# 8.9
# <class 'float'>

# %%
num_1 = '123'
num_2 = '456'
num_3 = num_1 + num_2
print(num_3)
print(type(num_3))
# Out:
# 123456
# <class 'str'>

# %%
num_1 = '123'
num_2 = 456
num_3 = num_1 + num_2
print(num_3)
print(type(num_3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 3
#       1 num_1 = '123'
#       2 num_2 = 456
# ----> 3 num_3 = num_1 + num_2
#       4 print(num_3)
#       5 print(type(num_3))
#
# TypeError: can only concatenate str (not "int") to str

# %%
num_1 = '123'
num_2 = '456'
num_3 = num_1 * 3
print(num_3)
print(type(num_3))
# Out:
# 123123123
# <class 'str'>

# %%
num1 = 123
print(id(num1))
num2 = 456
print(id(num2))
num1 = num1 + num2
print(num1)
print(id(num1))
print(type(num1))
# Out:
# 11757800
# 126390959244304
# 579
# 126390959143856
# <class 'int'>

# %%
result = None
print(type(result))
# Out:
# <class 'NoneType'>

# %% [markdown]
#  num1 или num_1

# %%
name = ''
print(type(name))
# Out:
# <class 'str'>

# %%
num_1 = 0.1
num_2 = 0.2
num_3 = num_1 + num_2
print(num_3)
print(type(num_3))
# Out:
# 0.30000000000000004
# <class 'float'>

# %%
num = 123.456789
print(type(num))
print(num)
num_1 = round(num)
print(type(num_1))
print(num_1)
num_2 = round(num, 2)
print(type(num_2))
print(num_2)
num_3 = round(num, -2)
print(type(num_3))
print(num_3)
# Out:
# <class 'float'>
# 123.456789
# <class 'int'>
# 123
# <class 'float'>
# 123.46
# <class 'float'>
# 100.0

# %%
num_1 = '123'
print(id(num_1))
print(type(num_1))
num_1 = int(num_1)
print(id(num_1))
print(type(num_1))
num_2 = 456
num_3 = num_1 + num_2
print(num_3)
print(type(num_3))
# Out:
# 126391142692592
# <class 'str'>
# 11757800
# <class 'int'>
# 579
# <class 'int'>

# %%
num_1 = '123'
print(id(num_1))
print(type(num_1))
num_1 = float(num_1)
print(id(num_1))
print(type(num_1))
num_2 = 456
num_3 = num_1 + num_2
print(num_3)
print(type(num_3))
# Out:
# 126391142692592
# <class 'str'>
# 126390990933552
# <class 'float'>
# 579.0
# <class 'float'>

# %%
num_1 = '123'
print(id(num_1))
print(type(num_1))
num_2 = 456
print(id(num_2))
num_2 = str(num_2)
print(id(num_2))
num_3 = num_1 + num_2
print(num_3)
print(type(num_3))
# Out:
# 126391142692592
# <class 'str'>
# 126390958581840
# 126391021840704
# 123456
# <class 'str'>

# %%
my_bool = True
print(my_bool)
print(type(my_bool))

my_bool = str(my_bool)
print(type(my_bool))
print(my_bool)
# Out:
# True
# <class 'bool'>
# <class 'str'>
# True

# %%
my_bool = False
print(my_bool)
print(type(my_bool))

my_bool = int(my_bool)
print(type(my_bool))
print(my_bool)
# Out:
# False
# <class 'bool'>
# <class 'int'>
# 0

# %%
my_item = ''
print(my_item)
print(type(my_item))

my_bool = bool(my_item)
print(type(my_bool))
print(my_bool)
# Out:
# <class 'str'>
# <class 'bool'>
# False

# %%
my_item = None
print(my_item)
print(type(my_item))

my_bool = bool(my_item)
print(type(my_bool))
print(my_bool)
# Out:
# None
# <class 'NoneType'>
# <class 'bool'>
# False

# %%
my_item = 0.0
print(my_item)
print(type(my_item))

my_bool = bool(my_item)
print(type(my_bool))
print(my_bool)
# Out:
# 0.0
# <class 'float'>
# <class 'bool'>
# False

# %%
name = 'Bob'
my_str = f'Привет, {name} {1 + 2} --- {type(my_str)} !'    #
my_str_2 = 'Привет, ' + name + str(1 + 2) + str(type(my_str)) + '!'    #
print(my_str)
print(my_str_2)
# Out:
# Привет, Bob 3 --- <class 'str'> !
# Привет, Bob3<class 'str'>!

# %%
name = 'Bob'
my_str = 'Привет, {name} {1 + 2} --- {type(my_str)} !'    #
print(my_str)
# Out:
# Привет, {name} {1 + 2} --- {type(my_str)} !
