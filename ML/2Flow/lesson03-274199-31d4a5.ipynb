# %%
age = 25

# %%
result = age >= 18
print(result)
# Out:
# True

# %%
if result:
    print("Вы совершеннолетний")
    print("Доступ разрешен")
print('Конец программы')
# Out:
# Вы совершеннолетний
# Доступ разрешен
# Конец программы

# %%
my_str_1 = 'abc'
my_str_2 = 'abc'
print(my_str_1 == my_str_2)
# Out:
# False

# %%
age = 17
if age >= 18:
    print("Вы совершеннолетний")
    print("Доступ разрешен")

else:
    print("Доступ запрещен")

print('Конец программы')
# Out:
# Доступ запрещен
# Конец программы

# %%
age = 67
if age >= 18:
    print("Вы совершеннолетний")
    print("Доступ разрешен")
    if age >= 65:
        print("Добро пожаловать в пенсионный режим")
    else:
        print("Добро пожаловать в обычный режим")
else:
    print("Доступ запрещен")

print('Конец программы')
# Out:
# Вы совершеннолетний
# Доступ разрешен
# Добро пожаловать в пенсионный режим
# Конец программы

# %%
age = 10
if age <= 7 :
    print("Вы ребенок")
elif age <= 18:
    print("Вы школьник")
elif age <= 65:
    print("Вы взрослый")
else:
    print("Вы пенсионер")

print('END')
# Out:
# Вы школьник
# END

# %%
result1 = (True and False)
result2= (False and True)
result3 = (True and True)
result4 = (False and False)

print(result1)
print(result2)
print(result3)
print(result4)
# Out:
# False
# False
# True
# False

# %%
result1 = (1 and 0)
result2 = (0 and 1)
result3 = (1 and 1)
result4 = (0 and 0)

print(result1)
print(result2)
print(result3)
print(result4)
# Out:
# 0
# 0
# 1
# 0

# %%
result1 = (True or False)
result2= (False or True)
result3 = (True or True)
result4 = (False or False)

print(result1)
print(result2)
print(result3)
print(result4)
# Out:
# True
# True
# True
# False

# %%
result1 = (1 or 0)
result2 = (0 or 1)
result3 = (1 or 1)
result4 = (0 or 0)

print(result1)
print(result2)
print(result3)
print(result4)
# Out:
# 100
# 1
# 1
# 0

# %%
result1 = not True
result2 = not False

print(result1)
print(result2)
# Out:
# False
# True

# %%
age = 10
if not age <= 7 :
    print("Вы взрослый")
# Out:
# Вы взрослый

# %%
age = 10
if age <= 7 :
    pass
else:
    print("Вы взрослый")
# Out:
#   Cell In[53], line 4
#     else:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
age = 21

if age >= 7 and age <= 7:
    print("Вы ребенок")
elif age > 7 and age <= 18:
    print("Вы школьник")
elif age > 18 and age <= 65:
    print("Вы взрослый")
else:
    print("Вы пенсионер")

print('END')
# Out:
# Вы взрослый
# END

# %%
age = 25
name = 'Bob'

if name == 'Bob' or age <= 7:
    print("Вы ребенок")
elif (name == 'Ann' and age <= 18) or (name == 'Bob' and age <= 25):
    print("Вы школьник")
elif name == 'Tom' and age <= 65:
    print("Вы взрослый")
else:
    print("Вы пенсионер")

print('END')
# Out:
# Вы ребенок
# END

# %%
age = 25
age += 5   # age = age + 5
age += 5
age += 5
age += 5

age
# Out:
# 45

# %%
age = 5
if age <= 7:
    print("Вы ребенок")
# Out:
# Вы ребенок

# %%
age = 3
result = True
while result:
    print(f"Вы ребенок. {age} лет")
    age += 1
    if age == 6:
        result = False

print('END')
# Out:
# Вы ребенок. 3 лет
# Вы ребенок. 4 лет
# Вы ребенок. 5 лет
# END

# %%
age = 3
result = True
while result:
    age += 1
    if age == 6 or age == 7:
        continue
    elif age == 10:
        break
    print(f"Вы ребенок. {age} лет")

print('END')
# Out:
# Вы ребенок. 4 лет
# Вы ребенок. 5 лет
# Вы ребенок. 8 лет
# Вы ребенок. 9 лет
# END

# %%
age = 3
result = True
while result:
    age += 1
    if age == 6 or age == 7:
        continue
    elif age == 10:
        result = False
    print(f"Вы ребенок. {age} лет")
else:
    print('Вышли по else')
print('END')
# Out:
# Вы ребенок. 4 лет
# Вы ребенок. 5 лет
# Вы ребенок. 8 лет
# Вы ребенок. 9 лет
# Вы ребенок. 10 лет
# Вышли по else
# END

# %%
age = 103
result = True
while result and age <= 100 and age >= 0:
    age += 1
    if age == 6 or age == 7:
        continue
    elif age == 10:
        result = False
    print(f"Вы ребенок. {age} лет")
else:
    print('Вышли по else')
print('END')
# Out:
# Вышли по else
# END

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in 1, 4, 7, 8, 9:
    print(i)
# Out:
# 1
# 4
# 7
# 8
# 9

# %%
for i in 1, True, 'abc', 8, 9:
    print(i)
# Out:
# 1
# True
# abc
# 8
# 9

# %%
my_list = [1, 2, 3, 4, 5, 6, 7]
for item in my_list:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
nums = range(7)
print(nums)
print(type(nums))
print(list(nums))
# Out:
# range(0, 7)
# <class 'range'>
# [0, 1, 2, 3, 4, 5, 6]

# %%
# nums = range(start, stop, step)
nums = range(0, 7, 1)
print(nums)
print(type(nums))
print(list(nums))
# Out:
# range(0, 7)
# <class 'range'>
# [0, 1, 2, 3, 4, 5, 6]

# %%
# nums = range(start, stop, step)
nums = range(0, 9, 2)
print(nums)
print(type(nums))
print(list(nums))
# Out:
# range(0, 9, 2)
# <class 'range'>
# [0, 2, 4, 6, 8]

# %%
# nums = range(start, stop, step)
nums = range(9, 0, -2)
print(nums)
print(type(nums))
print(list(nums))
# Out:
# range(9, 0, -2)
# <class 'range'>
# [9, 7, 5, 3, 1]

# %%
x = 100
y = 37
z = 10
for i in range(x, y, -z):
    print(i)
# Out:
# 100
# 90
# 80
# 70
# 60
# 50
# 40

# %%
for i in range(12):

    if i == 5 or i == 6:
        continue
    elif i == 9:
        print('Вышли по else1')
        break
    print(i)
else:
    print('Вышли по else')

print('END')
# Out:
# 0
# 1
# 2
# 3
# 4
# 7
# 8
# Вышли по else1
# END

# %%
my_list = [11, 12, 13, 14, 15, 16, 17]
for item in enumerate(my_list, start=100):
    print(item)
# Out:
# (100, 11)
# (101, 12)
# (102, 13)
# (103, 14)
# (104, 15)
# (105, 16)
# (106, 17)

# %%
my_list = [11, 12, 13, 14, 15, 16, 17]
for index, item in enumerate(my_list, start=1000):
    print(f'{index} - {item}')
# Out:
# 1000 - 11
# 1001 - 12
# 1002 - 13
# 1003 - 14
# 1004 - 15
# 1005 - 16
# 1006 - 17

# %%
import random

secret_number = random.randint(1, 100)
print(secret_number)

guess = None
while guess != secret_number:
    guess = int(input('Угадай число от 1 до 100'))
    if guess < secret_number:
        print('Число слишком маленькое')
    elif guess > secret_number:
        print('Число слишком большое')
else:
    print("Ты выиграл!")
# Out:
# 25
# Число слишком большое
# Число слишком большое
# Число слишком большое
# Число слишком маленькое
# Число слишком маленькое
# Число слишком маленькое
# Число слишком маленькое
# Число слишком маленькое
# Число слишком маленькое
# Ты выиграл!
