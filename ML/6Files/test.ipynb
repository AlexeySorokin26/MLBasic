# %%
from pathlib import Path

#dir_path = Path("qaz")
#dir_path.rmdir()

#file_path = Path("tmp.txt")
#print(file_path.is_file())

#with open("tmp.txt", 'a') as f:
#    f.write("\nnew text")   

Path("file.json").touch()    
    
import json 

info = {
    "title": "Some title",
    "page" : 3,
    "tags" :["list1", "list2"],
    "approved" : True
}

# serialization
json_str = json.dumps(info)
# desirialize
parsed_info = json.loads(json_str)
#print(parsed_info)

with open("info.json", 'w', encoding='utf-8') as json_file:
    json.dump(json_str, json_file)
with open("info.json", 'r') as json_file:
    #parsed_info = json.loads("".join(json_file.readlines()))
    parsed_info = json.load(json_file)
    print(parsed_info)
# Out:
# {"title": "Some title", "page": 3, "tags": ["list1", "list2"], "approved": true}

# %%
import csv

with open("data.csv", "r", newline='') as csv_file:
    reader = csv.reader(csv_file, delimiter='.')
    for row in reader:
        print(row)
# Out:
# ['Peter', '15', 'Moscow']
# ['Julia', '16', 'Peter']
# ['Ira', '17', 'Sochi']
